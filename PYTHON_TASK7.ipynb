# %%
import pandas as pd

# %%
df=pd.read_csv("financial_transactions.csv")

# %%
df
# Out:
#      Transaction_ID        Date Customer     Category     Product  Quantity  \
# 0                 1  2026-07-08      Anu  Electronics      Laptop         5
# 1                 2  2026-03-01   Nikhil   Stationery        File         1
# 2                 3  2026-05-31    Akhil   Stationery         Pen         9
# 3                 4  2026-07-15     Ravi      Grocery       Sugar         5
# 4                 5  2026-07-26    Meena      Grocery        Rice         6
# ..              ...         ...      ...          ...         ...       ...
# 495             496  2026-01-20    Priya     Clothing      Jacket         8
# 496             497  2026-02-03    Priya      Grocery        Rice         7
# 497             498  2026-08-26     Ravi  Electronics  Headphones         8
# 498             499  2026-04-02    Rahul   Stationery      Marker         8
# 499             500  2026-04-17   Swathi     Clothing       Shoes         2
#
#       Sales  Profit Payment_Method Region
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 10 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Transaction_ID  500 non-null    int64
#  1   Date            500 non-null    object
#  2   Customer        500 non-null    object
#  3   Category        500 non-null    object
#  4   Product         500 non-null    object
#  5   Quantity        500 non-null    int64
#  6   Sales           500 non-null    int64
#  7   Profit          500 non-null    int64
#  8   Payment_Method  500 non-null    object
#  9   Region          500 non-null    object
# dtypes: int64(4), object(6)
# memory usage: 39.2+ KB

# %%
df.head()
# Out:
#    Transaction_ID        Date Customer     Category Product  Quantity   Sales  \
# 0               1  2026-07-08      Anu  Electronics  Laptop         5  167990
# 1               2  2026-03-01   Nikhil   Stationery    File         1     111
# 2               3  2026-05-31    Akhil   Stationery     Pen         9    8181
# 3               4  2026-07-15     Ravi      Grocery   Sugar         5    3430
# 4               5  2026-07-26    Meena      Grocery    Rice         6    8748
#
#    Profit Payment_Method Region
# 0   21688    Net Banking  North
# 1      11    Net Banking  North
# 2    1051           Cash  South
# 3     436           Cash  North
# 4    1861            UPI  North

# %%
df.tail()
# Out:
#      Transaction_ID        Date Customer     Category     Product  Quantity  \
# 495             496  2026-01-20    Priya     Clothing      Jacket         8
# 496             497  2026-02-03    Priya      Grocery        Rice         7
# 497             498  2026-08-26     Ravi  Electronics  Headphones         8
# 498             499  2026-04-02    Rahul   Stationery      Marker         8
# 499             500  2026-04-17   Swathi     Clothing       Shoes         2
#
#       Sales  Profit Payment_Method Region
# 495   15624    4630    Credit Card  North
# 496    8351    1690    Net Banking   East
# 497  174320   15477    Net Banking  North
# 498   13336    2747     Debit Card  South
# 499   13882    2653    Net Banking   West

# %%
df["Date"]=pd.to_datetime(df["Date"])
df.dtypes
# Out:
# Transaction_ID             int64
# Date              datetime64[ns]
# Customer                  object
# Category                  object
# Product                   object
# Quantity                   int64
# Sales                      int64
# Profit                     int64
# Payment_Method            object
# Region                    object
# dtype: object

# %%
high_sales=df[df["Sales"]>70000]
high_sales
# Out:
#      Transaction_ID       Date Customer     Category     Product  Quantity  \
# 0                 1 2026-07-08      Anu  Electronics      Laptop         5
# 6                 7 2026-08-07    Sneha  Electronics      Laptop         4
# 7                 8 2026-02-23    Akhil    Furniture   Bookshelf         6
# 14               15 2026-04-22    Priya  Electronics    Keyboard         5
# 15               16 2026-08-11    Divya    Furniture        Desk         3
# ..              ...        ...      ...          ...         ...       ...
# 485             486 2026-04-09    Pooja  Electronics     Monitor        10
# 486             487 2026-02-04    Vijay    Furniture   Bookshelf         6
# 492             493 2026-07-10   Swathi    Furniture   Bookshelf         2
# 494             495 2026-08-22     Neha  Electronics  Headphones         4
# 497             498 2026-08-26     Ravi  Electronics  Headphones         8
#
#       Sales  Profit Payment_Method Region
# ...

# %%
high_Profit=df[df["Profit"]>80000]
high_Profit
# Out:
#      Transaction_ID       Date Customer     Category     Product  Quantity  \
# 109             110 2026-05-10    Akhil  Electronics  Headphones         7
# 110             111 2026-04-25   Swathi    Furniture        Desk        10
# 157             158 2026-03-20    Meena  Electronics  Headphones        10
# 166             167 2026-07-14   Aditya  Electronics  Smartphone         8
# 169             170 2026-05-29   Swathi  Electronics      Laptop        10
# 183             184 2026-02-07    Pooja  Electronics  Smartphone         5
# 191             192 2026-05-10   Swathi  Electronics    Keyboard         9
# 210             211 2026-05-22    Vijay  Electronics  Headphones         9
# 211             212 2026-07-16    Pooja  Electronics  Headphones         7
# 265             266 2026-07-06    Sneha  Electronics  Smartphone         9
# 277             278 2026-02-23     Ravi  Electronics  Smartphone        10
# ...

# %%
categort_avg=df[df["Category"]=="Furniture"]
categort_avg
# Out:
#      Transaction_ID       Date Customer   Category    Product  Quantity  \
# 7                 8 2026-02-23    Akhil  Furniture  Bookshelf         6
# 15               16 2026-08-11    Divya  Furniture       Desk         3
# 23               24 2026-08-28   Aditya  Furniture  Bookshelf         4
# 26               27 2026-04-25    Vijay  Furniture      Chair         4
# 27               28 2026-08-09   Swathi  Furniture  Bookshelf         4
# ..              ...        ...      ...        ...        ...       ...
# 478             479 2026-07-16   Anjali  Furniture      Chair         4
# 479             480 2026-02-26     Arun  Furniture  Bookshelf         2
# 480             481 2026-01-12    Priya  Furniture       Desk         9
# 486             487 2026-02-04    Vijay  Furniture  Bookshelf         6
# 492             493 2026-07-10   Swathi  Furniture  Bookshelf         2
#
#       Sales  Profit Payment_Method Region
# 7     75954   12261           Cash  South
# ...

# %%
df[(df["Sales"]>50000)&(df["Product"]=="Bookshelf")]
# Out:
#      Transaction_ID       Date Customer   Category    Product  Quantity  \
# 7                 8 2026-02-23    Akhil  Furniture  Bookshelf         6
# 23               24 2026-08-28   Aditya  Furniture  Bookshelf         4
# 30               31 2026-03-17    Kiran  Furniture  Bookshelf         9
# 236             237 2026-04-16   Nikhil  Furniture  Bookshelf         3
# 253             254 2026-03-26    Divya  Furniture  Bookshelf         4
# 266             267 2026-07-30    Sneha  Furniture  Bookshelf         9
# 320             321 2026-04-26     Ravi  Furniture  Bookshelf         2
# 342             343 2026-08-11    Rahul  Furniture  Bookshelf         8
# 354             355 2026-06-15    Rahul  Furniture  Bookshelf         6
# 365             366 2026-07-02   Aditya  Furniture  Bookshelf         5
# 399             400 2026-03-24    Vijay  Furniture  Bookshelf        10
# 427             428 2026-06-04    Rahul  Furniture  Bookshelf         6
# ...

# %%
df[(df["Sales"]>70000)&(df["Profit"]>90000)]
# Out:
#      Transaction_ID       Date Customer     Category     Product  Quantity  \
# 109             110 2026-05-10    Akhil  Electronics  Headphones         7
# 110             111 2026-04-25   Swathi    Furniture        Desk        10
# 157             158 2026-03-20    Meena  Electronics  Headphones        10
# 166             167 2026-07-14   Aditya  Electronics  Smartphone         8
# 169             170 2026-05-29   Swathi  Electronics      Laptop        10
# 191             192 2026-05-10   Swathi  Electronics    Keyboard         9
# 265             266 2026-07-06    Sneha  Electronics  Smartphone         9
# 277             278 2026-02-23     Ravi  Electronics  Smartphone        10
# 282             283 2026-03-17    Vijay    Furniture        Desk        10
# 287             288 2026-01-05     Arun  Electronics    Keyboard        10
# 298             299 2026-03-25     Arun  Electronics  Headphones        10
# ...

# %%
df.sort_values("Profit")
# Out:
#      Transaction_ID       Date Customer     Category     Product  Quantity  \
# 1                 2 2026-03-01   Nikhil   Stationery        File         1
# 217             218 2026-06-14   Aditya   Stationery    Notebook         1
# 389             390 2026-02-05    Pooja   Stationery        File         1
# 48               49 2026-03-30     Ravi   Stationery      Marker         1
# 245             246 2026-08-26    Priya      Grocery        Rice         3
# ..              ...        ...      ...          ...         ...       ...
# 157             158 2026-03-20    Meena  Electronics  Headphones        10
# 287             288 2026-01-05     Arun  Electronics    Keyboard        10
# 473             474 2026-08-11    Priya  Electronics  Smartphone         9
# 191             192 2026-05-10   Swathi  Electronics    Keyboard         9
# 298             299 2026-03-25     Arun  Electronics  Headphones        10
#
#       Sales  Profit Payment_Method Region
# ...

# %%
df.sort_values("Sales")
# Out:
#      Transaction_ID       Date Customer     Category     Product  Quantity  \
# 1                 2 2026-03-01   Nikhil   Stationery        File         1
# 245             246 2026-08-26    Priya      Grocery        Rice         3
# 217             218 2026-06-14   Aditya   Stationery    Notebook         1
# 389             390 2026-02-05    Pooja   Stationery        File         1
# 48               49 2026-03-30     Ravi   Stationery      Marker         1
# ..              ...        ...      ...          ...         ...       ...
# 191             192 2026-05-10   Swathi  Electronics    Keyboard         9
# 287             288 2026-01-05     Arun  Electronics    Keyboard        10
# 157             158 2026-03-20    Meena  Electronics  Headphones        10
# 169             170 2026-05-29   Swathi  Electronics      Laptop        10
# 277             278 2026-02-23     Ravi  Electronics  Smartphone        10
#
#       Sales  Profit Payment_Method Region
# ...

# %%
category_sales=df.groupby("Category")["Sales"].sum()
category_sales
# Out:
# Category
# Clothing        2248310
# Electronics    22256321
# Furniture      13063762
# Grocery          797596
# Stationery       601915
# Name: Sales, dtype: int64

# %%
category=df.groupby("Category")[["Sales","Profit"]].sum()
category
# Out:
#                 Sales   Profit
# Category
# Clothing      2248310   444567
# Electronics  22256321  4258542
# Furniture    13063762  2399870
# Grocery        797596   148153
# Stationery     601915   108090

# %%
category=df.groupby("Category")[["Sales","Profit"]].sum()
category
# Out:
#                 Sales   Profit
# Category
# Clothing      2248310   444567
# Electronics  22256321  4258542
# Furniture    13063762  2399870
# Grocery        797596   148153
# Stationery     601915   108090

# %%
Customer=df.groupby("Customer")[["Sales","Profit"]].sum()
Customer
# Out:
#             Sales  Profit
# Customer
# Aditya    1637408  253331
# Akhil     2088969  437192
# Anjali    1636343  247873
# Anu       2181621  425429
# Arun      2817469  654697
# Divya     1282769  259239
# Kiran     1591470  313723
# Lakshmi   1833916  329242
# Manoj     1576864  246208
# Meena     2793148  491398
# Neha      1590938  262175
# Nikhil    1784018  320731
# Pooja     2243126  481712
# Priya     2323539  496235
# Rahul      826114  147428
# Ravi      2354172  390052
# Sneha     1410967  284564
# Suresh    1658293  267532
# Swathi    3564632  722643
# Vijay     1772128  327818

# %%
best_customer=Customer["Sales"].idxmax
print("best customer:",best_customer)
print("Sales:",Customer.max())
# Out:
# best customer: <bound method Series.idxmax of Customer
# Aditya     1637408
# Akhil      2088969
# Anjali     1636343
# Anu        2181621
# Arun       2817469
# Divya      1282769
# Kiran      1591470
# Lakshmi    1833916
# Manoj      1576864
# Meena      2793148
# Neha       1590938
# Nikhil     1784018
# Pooja      2243126
# Priya      2323539
# Rahul       826114
# Ravi       2354172
# Sneha      1410967
# Suresh     1658293
# Swathi     3564632
# Vijay      1772128
# Name: Sales, dtype: int64>
# Sales: Sales     3564632
# Profit     722643
# dtype: int64

# %%
sales_report=df.groupby("Category").agg(
    Total_sales=("Sales","sum"),
    Total_Profit=("Profit","sum"),
    average_sales=("Sales","mean"),
    average_quantity=("Quantity","sum")
)
print(sales_report)
# Out:
#              Total_sales  Total_Profit  average_sales  average_quantity
# Category
# Clothing         2248310        444567   23666.421053               526
# Electronics     22256321       4258542  229446.608247               529
# Furniture       13063762       2399870  114594.403509               630
# Grocery           797596        148153    7975.960000               577
# Stationery        601915        108090    6403.351064               532

# %%
pivot=pd.pivot_table(
    df,
    values="Sales",
    index="Customer",
    columns="Category",
    aggfunc="sum",
    fill_value=0
)
print(pivot)
# Out:
# Category  Clothing  Electronics  Furniture  Grocery  Stationery
# Customer
# Aditya       60234      1135900     391540     1420       48314
# Akhil       190418       995544     826174    58906       17927
# Anjali      112207       574194     890550    11286       48106
# Anu         379425       498958    1224504    33117       45617
# Arun        119341      1984593     637901    75634           0
# Divya       113546       490594     619079    34740       24810
# Kiran        10363       667444     841585    42948       29130
# Lakshmi      39421       691204    1084851     8963        9477
# Manoj        28025       954934     498947    64366       30592
# Meena       199191      1891910     653513    25406       23128
# Neha         33388       792018     675251    50727       39554
# Nikhil       38690      1191851     495740    43606       14131
# Pooja       138606      1764932     258293    40661       40634
# ...

# %%
df["Profit_margin"]=(df["Profit"]/df["Sales"])*100

# %%
df["Profit_margin"]
# Out:
# 0      12.910292
# 1       9.909910
# 2      12.846840
# 3      12.711370
# 4      21.273434
#          ...
# 495    29.633897
# 496    20.237097
# 497     8.878499
# 498    20.598380
# 499    19.111079
# Name: Profit_margin, Length: 500, dtype: float64
