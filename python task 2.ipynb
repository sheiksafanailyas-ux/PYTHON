# %%
balance=2500
customer = {
    "name": "Amit",
    "balance": 5000}
if (balance>=3000):
    print("Good balance",balance)
else:
    print("Low balance",balance)
# Out:
# Low balance 2500

# %%
account = ("Priya", "Savings")
if account[1] == "Savings":
    print("Savings Account")
# Out:
# Savings Account

# %%
customer=["kamran","diviyu","ruchi","ummel"]
for name in customer:
    print(name)
# Out:
# kamran
# diviyu
# ruchi
# ummel

# %%
transactions = [500, -200, 1000, -700]

for amount in transactions:
    if amount > 0:
        print("Credit")
    elif amount < 0:
        print("Debit")
# Out:
# Credit
# Debit
# Credit
# Debit

# %%
transactions = [2000, 6000, 4500, 8000, 3000]

for amount in transactions:
    if amount > 5000:
        print("Large")
    else:
        print("Small")
# Out:
# Small
# Large
# Small
# Large
# Small

# %%
balance = 10000

amount = int(input("Enter debit amount: "))

if amount <= balance:
    print("Debit successful")
else:
    print("Insufficient balance")
# Out:
# Enter debit amount:  5000
# Debit successful

# %%
account = {"balance": 8000}

amount = int(input("Enter amount: "))

if amount <= account["balance"]:
    account["balance"] = account["balance"] - amount
    print("New balance:", account["balance"])
else:
    print("Not enough balance")
# Out:
# Enter amount:  9000
# Not enough balance
