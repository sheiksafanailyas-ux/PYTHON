# %%
try:
    balance=int(input("enter your cash book balance:"))
    n=int(input("enter the number of transactions:"))

    transactions=[]
    for i in range(n):
        print("\n Transaction",i+1)
        try:
            amount=int(input("enter the amount:"))
            t_type=input("Debit or Credit:")
            transactions.append([amount,t_type])
        except ValueError:
            print("Invailid input, enter a vaild input")
        for transaction in transactions:
            amount=transaction[0]
            t_type=transaction[1]
        if t_type.lower()=="credit":
            balance=balance+amount 
        elif t_type.upper()=="DEBIT":
            balance=balance-amount
        else:
            print("invalid input")
        print("Final REconciled Balance:",balance)
except ValueError:
    print("invalid input,enter the valid input")
# Out:
# enter your cash book balance: 20000
# enter the number of transactions: 2
#  Transaction 1
# enter the amount: 1000
# Debit or Credit: DEBIT
# Final REconciled Balance: 19000
#
#  Transaction 2
# enter the amount: 15000
# Debit or Credit: credit
# Final REconciled Balance: 34000
